-- %%
Select team_name,
count(1) as total_races,
sum(calculated_points) as total_points,
round(AVG(calculated_points),2) AS avg_points from f1_presentation.calculated_race_results
group by team_name
HAVING total_races >= 100
order by avg_points desc
