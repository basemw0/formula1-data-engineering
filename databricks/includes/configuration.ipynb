# %%
raw_folder_path = '/Volumes/f1_ws/raw/raw-data'
processed_folder_path = '/Volumes/f1_ws/processed/processed-data'
presentation_folder_path = '/Volumes/f1_ws/presentation/presentation-data'
api_raw_path = '/Volumes/f1_ws/raw/raw-data/jolpica-api'
